# %%
import pandas as pd   # pandas -> name of library    pd -> alias

# %%
# read_csv() ->pandas method    argument/paremeter -> "filename.csv" , 'filename.csv'

# %%
# dataframe is a tabular form to represent your data
df = pd.read_csv("trainingData.csv")

# %%
# Created Dataframe Named 'df' which contains data from trainingData.csv file

# %%
df.head(15)
# Out:
#      Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0   LP001002   Male      No          0      Graduate            No
# 1   LP001003   Male     Yes          1      Graduate            No
# 2   LP001005   Male     Yes          0      Graduate           Yes
# 3   LP001006   Male     Yes          0  Not Graduate            No
# 4   LP001008   Male      No          0      Graduate            No
# 5   LP001011   Male     Yes          2      Graduate           Yes
# 6   LP001013   Male     Yes          0  Not Graduate            No
# 7   LP001014   Male     Yes         3+      Graduate            No
# 8   LP001018   Male     Yes          2      Graduate            No
# 9   LP001020   Male     Yes          1      Graduate            No
# 10  LP001024   Male     Yes          2      Graduate            No
# 11  LP001027   Male     Yes          2      Graduate           NaN
# 12  LP001028   Male     Yes          2      Graduate            No
# ...

# %%
df.tail(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 604  LP002959  Female     Yes          1      Graduate            No
# 605  LP002960    Male     Yes          0  Not Graduate            No
# 606  LP002961    Male     Yes          1      Graduate            No
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 604            12000                0.0       496.0             360.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.shape
# Out:
# (614, 13)

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.values
# Out:
# array([['LP001002', 'Male', 'No', ..., 1.0, 'Urban', 'Y'],
#        ['LP001003', 'Male', 'Yes', ..., 1.0, 'Rural', 'N'],
#        ['LP001005', 'Male', 'Yes', ..., 1.0, 'Urban', 'Y'],
#        ...,
#        ['LP002983', 'Male', 'Yes', ..., 1.0, 'Urban', 'Y'],
#        ['LP002984', 'Male', 'Yes', ..., 1.0, 'Urban', 'Y'],
#        ['LP002990', 'Female', 'No', ..., 0.0, 'Semiurban', 'N']],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=614, step=1)

# %%
df.sort_values("ApplicantIncome")
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 216  LP001722    Male     Yes          0      Graduate            No
# 468  LP002502  Female     Yes          2  Not Graduate           NaN
# 600  LP002949  Female      No         3+      Graduate           NaN
# 500  LP002603  Female      No          0      Graduate            No
# 188  LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 185  LP001640    Male     Yes          0      Graduate           Yes
# 155  LP001536    Male     Yes         3+      Graduate            No
# 171  LP001585     NaN     Yes         3+      Graduate            No
# 333  LP002101    Male     Yes          0      Graduate           NaN
# 409  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.sort_values("ApplicantIncome" , ascending = False)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 409  LP002317    Male     Yes         3+      Graduate            No
# 333  LP002101    Male     Yes          0      Graduate           NaN
# 171  LP001585     NaN     Yes         3+      Graduate            No
# 155  LP001536    Male     Yes         3+      Graduate            No
# 185  LP001640    Male     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 188  LP001644     NaN     Yes          0      Graduate           Yes
# 500  LP002603  Female      No          0      Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 468  LP002502  Female     Yes          2  Not Graduate           NaN
# 216  LP001722    Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.sort_values(["ApplicantIncome" , "CoapplicantIncome" ] , ascending = [True , False])
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 216  LP001722    Male     Yes          0      Graduate            No
# 468  LP002502  Female     Yes          2  Not Graduate           NaN
# 600  LP002949  Female      No         3+      Graduate           NaN
# 500  LP002603  Female      No          0      Graduate            No
# 188  LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 185  LP001640    Male     Yes          0      Graduate           Yes
# 155  LP001536    Male     Yes         3+      Graduate            No
# 171  LP001585     NaN     Yes         3+      Graduate            No
# 333  LP002101    Male     Yes          0      Graduate           NaN
# 409  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
requiredColumns = ['Gender' , 'Married' , 'Education' , 'ApplicantIncome']

# %%
df[requiredColumns]
# Out:
#      Gender Married     Education  ApplicantIncome
# 0      Male      No      Graduate             5849
# 1      Male     Yes      Graduate             4583
# 2      Male     Yes      Graduate             3000
# 3      Male     Yes  Not Graduate             2583
# 4      Male      No      Graduate             6000
# ..      ...     ...           ...              ...
# 609  Female      No      Graduate             2900
# 610    Male     Yes      Graduate             4106
# 611    Male     Yes      Graduate             8072
# 612    Male     Yes      Graduate             7583
# 613  Female      No      Graduate             4583
#
# [614 rows x 4 columns]

# %%
df[['Gender' , 'Married' , 'Education' , 'ApplicantIncome']]
# Out:
#      Gender Married     Education  ApplicantIncome
# 0      Male      No      Graduate             5849
# 1      Male     Yes      Graduate             4583
# 2      Male     Yes      Graduate             3000
# 3      Male     Yes  Not Graduate             2583
# 4      Male      No      Graduate             6000
# ..      ...     ...           ...              ...
# 609  Female      No      Graduate             2900
# 610    Male     Yes      Graduate             4106
# 611    Male     Yes      Graduate             8072
# 612    Male     Yes      Graduate             7583
# 613  Female      No      Graduate             4583
#
# [614 rows x 4 columns]

# %%
#df['Applicant Income']      # Applicant Income
#df.Applicant Income   # limited  Alphabet,Number,Underscore

# %%
df.Gender == 'Male'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 609    False
# 610     True
# 611     True
# 612     True
# 613    False
# Name: Gender, Length: 614, dtype: bool

# %%
df['Gender'] == 'Male'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 609    False
# 610     True
# 611     True
# 612     True
# 613    False
# Name: Gender, Length: 614, dtype: bool

# %%
maleEntries = df.Gender == 'Male'
femaleEntries = df['Gender'] == 'Female'

# %%
df[maleEntries]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 1    LP001003   Male     Yes          1      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 607  LP002964   Male     Yes          2  Not Graduate            No
# 608  LP002974   Male     Yes          0      Graduate            No
# 610  LP002979   Male     Yes         3+      Graduate            No
# 611  LP002983   Male     Yes          1      Graduate            No
# 612  LP002984   Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
df[df['Gender'] == 'Female']
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 17   LP001036  Female      No          0      Graduate            No
# 29   LP001087  Female      No          2      Graduate           NaN
# 37   LP001112  Female     Yes          0      Graduate            No
# 45   LP001137  Female      No          0      Graduate            No
# 48   LP001146  Female     Yes          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 587  LP002917  Female      No          0  Not Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 604  LP002959  Female     Yes          1      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df[df['ApplicantIncome'] < 5000]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
Income = df['ApplicantIncome'] > 5000
Co_Income = df['CoapplicantIncome'] > 1000
df[Income & Co_Income]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 5    LP001011   Male     Yes          2      Graduate           Yes
# 9    LP001020   Male     Yes          1      Graduate            No
# 21   LP001046   Male     Yes          1      Graduate            No
# 34   LP001100   Male      No         3+      Graduate            No
# 58   LP001198   Male     Yes          1      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 536  LP002734   Male     Yes          0      Graduate            No
# 555  LP002792   Male     Yes          1      Graduate            No
# 562  LP002820   Male     Yes          0      Graduate            No
# 571  LP002847   Male     Yes        NaN      Graduate            No
# 573  LP002862   Male     Yes          2  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 5               5417             4196.0       267.0             360.0
# ...

# %%
df[(df['ApplicantIncome'] > 5000) & (df['CoapplicantIncome'] > 1000)]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 5    LP001011   Male     Yes          2      Graduate           Yes
# 9    LP001020   Male     Yes          1      Graduate            No
# 21   LP001046   Male     Yes          1      Graduate            No
# 34   LP001100   Male      No         3+      Graduate            No
# 58   LP001198   Male     Yes          1      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 536  LP002734   Male     Yes          0      Graduate            No
# 555  LP002792   Male     Yes          1      Graduate            No
# 562  LP002820   Male     Yes          0      Graduate            No
# 571  LP002847   Male     Yes        NaN      Graduate            No
# 573  LP002862   Male     Yes          2  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 5               5417             4196.0       267.0             360.0
# ...

# %%
# isin()

Single = df['Married'].isin(['No'])
df[Single]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 15   LP001032    Male      No          0      Graduate            No
# 16   LP001034    Male      No          1  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 597  LP002943    Male      No        NaN      Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 603  LP002958    Male      No          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df[df['Married'].isin(['No'])]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 15   LP001032    Male      No          0      Graduate            No
# 16   LP001034    Male      No          1  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 597  LP002943    Male      No        NaN      Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 603  LP002958    Male      No          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df[df['Property_Area'].isin(['Urban' , 'Semiurban'])]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 605  LP002960    Male     Yes          0  Not Graduate            No
# 606  LP002961    Male     Yes          1      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
